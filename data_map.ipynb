# %%
import pandas as pd

# %%
datos = {
    "ARA": "Salta", 
    "ARB": "Buenos Aires", 
    "ARC": "Ciudad de Buenos Aires", 
    "ARD": "San Luis", 
    "ARE": "Entre Ríos", 
    "ARF": "La Rioja", 
    "ARG": "Santiago del Estero", 
    "ARH": "Chaco", 
    "ARJ": "San Juan", 
    "ARK": "Catamarca", 
    "ARL": "La Pampa", 
    "ARM": "Mendoza", 
    "ARN": "Misiones", 
    "ARP": "Formosa", 
    "ARQ": "Neuquén", 
    "ARR": "Río Negro", 
    "ARS": "Santa Fe", 
    "ART": "Tucumán", 
    "ARU": "Chubut", 
    "ARV": "Tierra del Fuego", 
    "ARW": "Corrientes", 
    "ARX": "Córdoba", 
    "ARY": "Jujuy", 
    "ARZ": "Santa Cruz"
}

# %%
provincias = pd.DataFrame(list(datos.items()),columns=["id","provincia"])

# %%
provincias
# Out:
#      id               provincia
# 0   ARA                   Salta
# 1   ARB            Buenos Aires
# 2   ARC  Ciudad de Buenos Aires
# 3   ARD                San Luis
# 4   ARE              Entre Ríos
# 5   ARF                La Rioja
# 6   ARG     Santiago del Estero
# 7   ARH                   Chaco
# 8   ARJ                San Juan
# 9   ARK               Catamarca
# 10  ARL                La Pampa
# 11  ARM                 Mendoza
# 12  ARN                Misiones
# 13  ARP                 Formosa
# 14  ARQ                 Neuquén
# 15  ARR               Río Negro
# 16  ARS                Santa Fe
# 17  ART                 Tucumán
# 18  ARU                  Chubut
# 19  ARV        Tierra del Fuego
# 20  ARW              Corrientes
# 21  ARX                 Córdoba
# 22  ARY                   Jujuy
# 23  ARZ              Santa Cruz

# %%
provincias.to_csv("provincias.csv", index=False, encoding='latin1')
